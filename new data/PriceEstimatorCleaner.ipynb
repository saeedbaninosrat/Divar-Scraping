# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
import matplotlib.pyplot as plt
import re

# %% [markdown]
# #### Change Excel to csv file

# %%
read_file = pd.read_excel('all cars.xlsx')
read_file.to_csv("allcars.csv", encoding='utf-8-sig', index=None,
                 header=True)

# %% [markdown]
# #### ReadCSV

# %%
df = pd.read_csv(r"allcars.csv")
df
# Out:
#                             Page link         Infos MotorState ChassisState  \
# 0       https://divar.ir/v/-/gYRGLfbt   Lamari Eama       سالم  سالم و پلمپ
# 1       https://divar.ir/v/-/wYt8L1si   Lamari Eama        NaN          NaN
# 2       https://divar.ir/v/-/wYtUeSUm   Lamari Eama        NaN  سالم و پلمپ
# 3       https://divar.ir/v/-/wYoE4qoZ   Lamari Eama       سالم          NaN
# 4       https://divar.ir/v/-/wYiINhA9   Lamari Eama       سالم  سالم و پلمپ
# ...                               ...           ...        ...          ...
# 316012  https://divar.ir/v/-/wYmwguxW  یوآز پاتریوت       سالم  سالم و پلمپ
# 316013  https://divar.ir/v/-/wYVcLMbm  یوآز پاتریوت       سالم  سالم و پلمپ
# 316014  https://divar.ir/v/-/wYjgQJkZ  یوآز پاتریوت       سالم  سالم و پلمپ
# 316015  https://divar.ir/v/-/wYhgfJlr  یوآز پاتریوت       سالم  سالم و پلمپ
# 316016  https://divar.ir/v/-/wYeY12Oi    یوآز پیکاپ       سالم  سالم و پلمپ
#
# ...

# %% [markdown]
# #### Define dictionary Age

# %%
Age = []
x = 0
for i in df["Year"]:
    # print(i)
    if (i) > 1600:
        Age.append(2022-i)
        x += 1
    elif (i) < 1600:
        Age.append(1401-i)
        x += 1
        
df['Age'] = Age

# %%
for i in df["Price"]:
    i = i.replace("٬", "")
    i = float(i)
    print(type(i))
    
df['Price'].astype(float)
# df['Price'] = df['Price']
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ...

# %%
df[["Infos", "Age", "Usage", "Price"]]
# Out:
#                Infos  Age   Usage          Price
# 0        Lamari Eama    0       0  ۱٬۰۰۰٬۰۰۰٬۰۰۰
# 1        Lamari Eama    0       ۰  ۱٬۲۳۰٬۰۰۰٬۰۰۰
# 2        Lamari Eama    0       ۰  ۱٬۲۴۰٬۰۰۰٬۰۰۰
# 3        Lamari Eama    0       ۰  ۱٬۲۷۰٬۰۰۰٬۰۰۰
# 4        Lamari Eama    0       0  ۱٬۲۸۰٬۰۰۰٬۰۰۰
# ...              ...  ...     ...            ...
# 316012  یوآز پاتریوت    1  ۳۰٬۰۰۰    ۹۳۰٬۰۰۰٬۰۰۰
# 316013  یوآز پاتریوت    1  ۳۰٬۰۰۰    ۹۳۰٬۰۰۰٬۰۰۰
# 316014  یوآز پاتریوت    1   ۸٬۵۰۰    ۹۸۰٬۰۰۰٬۰۰۰
# 316015  یوآز پاتریوت    1  ۱۴٬۰۰۰    ۹۹۰٬۰۰۰٬۰۰۰
# 316016    یوآز پیکاپ    1  ۱۲٬۰۰۰  ۱٬۱۰۰٬۰۰۰٬۰۰۰
#
# [316017 rows x 4 columns]

# %% [markdown]
# #### Brand and type dictionary

# %%
# brandDic = {}
# brandDic ['آئودی'] = []
# brandDic ['آریا'] = []
# brandDic ['آریسان'] = []
# brandDic ['آلفارومئو'] = []
# brandDic ['آمیکو'] = []
# brandDic ['اپل'] = []
# brandDic ['اس دبلیو ام'] = []
# brandDic ['اسمارت'] = []
# brandDic ['الدزمبیل'] = []
# brandDic ['ام جی'] = []
# brandDic ['ام وی ام'] = []
# brandDic ['ایسوزو'] = []
# brandDic ['اینرودز'] = []
# brandDic ['اینفینیتی'] = []
# brandDic ['ب ام و'] = []
# brandDic ['بایک'] = []
# brandDic ['برلیانس'] = []
# brandDic ['بسترن'] = []
# brandDic ['بنز'] = []
# brandDic ['بورگوارد'] = []
# brandDic ['بی وای دی'] = []
# brandDic ['بیسو'] = []
# brandDic ['بیوک'] = []
# brandDic ['پاژن'] = []
# brandDic ['پراید'] = []
# brandDic ['پروتون'] = []
# brandDic ['پژو'] = []
# brandDic ['پورشه'] = []
# brandDic ['پونتیاک'] = []
# brandDic ['پیکان'] = []
# brandDic ['تارا'] = []
# brandDic ['تویوتا'] = []
# brandDic ['تیبا'] = []
# brandDic ['جک'] = []
# brandDic ['جی ام سی GMC'] = []
# brandDic ['جِی ام سی JMC'] = []
# brandDic ['جیپ'] = []
# brandDic ['جیلی'] = []
# brandDic ['چانگان'] = []
# brandDic ['چری'] = []
# brandDic ['داتسون'] = []
# brandDic ['دامای'] = []
# brandDic ['دانگ فنگ'] = []
# brandDic ['دایون'] = []
# brandDic ['دنا'] = []
# brandDic ['دوج'] = []
# brandDic ['دوو'] = []
# brandDic ['دی اس'] = []
# brandDic ['دیگنیتی'] = []
# brandDic ['رانا'] = []
# brandDic ['راین'] = []
# brandDic ['رنو'] = []
# brandDic ['ریگان'] = []
# brandDic ['زامیاد'] = []
# brandDic ['زوتی'] = []
# brandDic ['سانگ یانگ'] = []
# brandDic ['ساینا'] = []
# brandDic ['سئات'] = []
# brandDic ['سمند'] = []
# brandDic ['سوئیست'] = []
# brandDic ['سوبارو'] = []
# brandDic ['سوزوکی'] = []
# brandDic ['سیتروئن'] = []
# brandDic ['سیناد'] = []
# brandDic ['شاهین'] = []
# brandDic ['شورولت'] = []
# brandDic ['فردا'] = []
# brandDic ['فوتون'] = []
# brandDic ['فورد'] = []
# brandDic ['فولکس'] = []
# brandDic ['فونیکس'] = []
# brandDic ['فیات'] = []
# brandDic ['فیدلیتی'] = []
# brandDic ['کاپرا'] = []
# brandDic ['کادیلاک'] = []
# brandDic ['کارا'] = []
# brandDic ['کوییک'] = []
# brandDic ['کی ام سی'] = []
# brandDic ['کیا'] = []
# brandDic ['گریت وال'] = []
# brandDic ['گک'] = []
# brandDic ['لاماری'] = []
# brandDic ['لکسوس'] = []
# brandDic ['لندرور'] = []
# brandDic ['لندمارک'] = []
# brandDic ['لوتوس'] = []
# brandDic ['لیفان'] = []
# brandDic ['لینکلن'] = []
# brandDic ['مازراتی'] = []
# brandDic ['مزدا'] = []
# brandDic ['مکث موتور'] = []
# brandDic ['میتسوبیشی'] = []
# brandDic ['مینی'] = []
# brandDic ['نیسان'] = []
# brandDic ['ولوو'] = []
# brandDic ['ون'] = []
# brandDic ['هامر'] = []
# brandDic ['هاوال'] = []
# brandDic ['هایما'] = []
# brandDic ['هن تنگ'] = []
# brandDic ['هوندا'] = []
# brandDic ['هیلمن'] = []
# brandDic ['هیوسو'] = []
# brandDic ['هیوندای'] = []
# brandDic ['یوآز'] = []

# %% [markdown]
# #### Locate

# %%
# def locate(i):
#     return df[i:(i+1)]
# # df[2:3]
# locate(0)

# %%
# for i in range(len(df.index)):
#     # print(type(df['Price'][i]))
#         # print(df.loc[[79]])
#         # df.drop(index=[i], axis=0, inplace=True)
#         # print("diiiiiiiiiiiizzzzzzz")
        
#         # df.drop([i])
#         # df[i]
#         # df.loc[:,i]
    
#     # # print(type(i))
#     if type(df['Usage'][i]) ==  str:
#         df['Usage'][i] = int((df['Usage'][i]).replace('٬', '').replace('\u200c', ''))
        
#     if type(df['Price'][i]) ==  str:
#         df['Price'][i] = float((df['Price'][i]).replace('٬', '').replace('\u200c', ''))
    
#     if type(df['Year'][i]) ==  str:
#         df['Year'][i] = int((df['Year'][i]).replace('٬', '').replace('\u200c', ''))
#         # (df['Price'][i]).replace(",","")
#         # print(df['Price'][i])
#         # print(i)

# %%
# # for (k, v) in map:
# #     for c in v:
# #         text = text.replace(c, k)

# # def processString3(txt):
# #   txt = txt.replace('\u200c', '')

# # for i in df["Infos"]:
# #   processString3(i)
# # processString3(mimi)
# # processString3(txt)
# print(df.Infos.nunique())
# print(df.Infos.unique())

# %% [markdown]
# # 3

# %% [markdown]
# #### Renaming the column names

# %%
# df = df.rename({'Year': 'Age'}, axis=1)  # new method

# %% [markdown]
# #### a code for normalizing the strings

# %%
map = dict()
map[' '] = ['‌']
map['آ'] = []
map['ب'] = []
map['پ'] = []
map['ت'] = ['ٿ', 'ټ', 'ٺ', 'ت', 'ٹ']
map['ث'] = ['ٽ', 'ث']
map['ج'] = []
map['چ'] = ['ڇ', 'چ', 'ڄ', 'ڃ']
map['ح'] = ['ځ', 'ح']
map['خ'] = ['ڿ', 'خ', 'څ', 'ڂ', 'خ']
map['د'] = ['ډ', 'ڈ', 'ۮ', 'د']
map['ذ'] = ['ڐ', 'ڏ', 'ڎ', 'ڍ', 'ڌ', 'ڊ', 'ڋ', 'ذ']
map['ر'] = ['ږ', 'ڕ', 'ڔ', 'ړ', 'ڒ', 'ر']
map['ز'] = []
map['ژ'] = ['ۯ', 'ڙ', 'ژ', 'ڗ']
map['س'] = ['ښ', 'س']
map['ش'] = ['ۺ', 'ڜ', 'ڛ', 'ش']
map['ص'] = ['ص', 'ڝ']
map['ض'] = ['ۻ', 'ض', 'ڞ']
map['ط'] = []
map['ظ'] = ['ڟ', 'ظ']
map['ع'] = []
map['غ'] = ['ۼ', 'غ', 'ڠ']
map['ف'] = ['ڦ', 'ڥ', 'ڤ', 'ڣ', 'ڢ', 'ڡ', 'ف']
map['ق'] = ['ڨ', 'ڧ', 'ٯ', 'ق']
map['ک'] = ['ؼ', 'ػ', 'ڪ', 'ک', 'ګ', 'ڬ', 'ڭ', 'ك', 'ڮ']
map['گ'] = ['گ', 'ڰ', 'ڱ', 'ڲ', 'ڳ', 'ڴ']
map['ل'] = ['ڵ', 'ڶ', 'ڷ', 'ڸ', 'ل']
map['م'] = ['۾', 'م']
map['ن'] = ['ن', 'ڽ', 'ڼ', 'ڻ', 'ں', 'ڹ']
map['و'] = ['ؤ', 'و', 'ٷ', 'ٶ', 'ۏ', 'ۋ', 'ۊ', 'ۉ', 'ۈ', 'ۇ', 'ۆ', 'ۅ', 'ۄ']
map['ھ'] = ['ۿ', 'ھ']
map['ه'] = ['ە', 'ۂ', 'ہ', 'ۀ', 'ه']
map['ة'] = ['ة', 'ۃ']
map['ی'] = ['ئ', 'ؠ', 'ؿ', 'ؾ', 'ؽ', 'ي', 'ى', 'ٸ', 'ی', 'ۍ', 'ێ', 'ۑ', 'ې', 'ۓ', 'ے']

text = "unnormal tex"
for (k, v) in map:
    for c in v:
        text = text.replace(c, k)

# %% [markdown]
# # 5

# %%
x = df[['Age', 'Usage']]    # The x axis represents the age and the Usage
y= df['Price']              # The y axis represents the price

regression = linear_model.LinearRegression()
regression.fit(x,y)



# plt.scatter(df['Age'], y, color='red')
# plt.scatter(df['Usage'], y, color='green')
# plt.title('Pricetable')
# plt.xlabel('Independents')
# plt.ylabel('Dependents')
# plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\saeed\Desktop\Mozayedegar\Divar-Scraping\new data\PriceEstimatorCleaner.ipynb Cell 23 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/new%20data/PriceEstimatorCleaner.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> y= df['Price']              # The y axis represents the price
#       <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/new%20data/PriceEstimatorCleaner.ipynb#X31sZmlsZQ%3D%3D?line=3'>4</a> regression = linear_model.LinearRegression()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/new%20data/PriceEstimatorCleaner.ipynb#X31sZmlsZQ%3D%3D?line=4'>5</a> regression.fit(x,y)
#
# ...

# %%
print("INTERCEPT:\n", regression.intercept_)

# %%
print("Coefficient:\n" , regression.coef_)

# %%
print(df.Infos.nunique())
print(df.Infos.unique())

# %%
pd.read_json(r"C:\Users\saeed\Downloads\car.json", encoding = "utf8")
