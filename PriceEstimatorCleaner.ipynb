# %% [markdown]
# # Cleaning

# %% [markdown]
# #### Import dictionaries

# %%
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
import matplotlib.pyplot as plt
import re
import numpy as np

# %% [markdown]
# #### Change Excel to csv file

# %%
read_file = pd.read_excel('all cars.xlsx')
read_file.to_csv("allcars.csv", encoding='utf-8-sig', index=None,
                 header=True)

# %% [markdown]
# #### ReadCSV

# %%
df = pd.read_csv(r"all.csv")
df
# Out:
#         Unnamed: 0                      Page link         Infos MotorState  \
# 0                0  https://divar.ir/v/-/gYRGLfbt   Lamari Eama       سالم
# 1                1  https://divar.ir/v/-/wYt8L1si   Lamari Eama        NaN
# 2                2  https://divar.ir/v/-/wYtUeSUm   Lamari Eama        NaN
# 3                3  https://divar.ir/v/-/wYoE4qoZ   Lamari Eama       سالم
# 4                4  https://divar.ir/v/-/wYiINhA9   Lamari Eama       سالم
# ...            ...                            ...           ...        ...
# 316012      316012  https://divar.ir/v/-/wYmwguxW  یوآز پاتریوت       سالم
# 316013      316013  https://divar.ir/v/-/wYVcLMbm  یوآز پاتریوت       سالم
# 316014      316014  https://divar.ir/v/-/wYjgQJkZ  یوآز پاتریوت       سالم
# 316015      316015  https://divar.ir/v/-/wYhgfJlr  یوآز پاتریوت       سالم
# 316016      316016  https://divar.ir/v/-/wYeY12Oi    یوآز پیکاپ       سالم
#
#        ChassisState FrontChassis BackChassis          BodyState Insurance  \
# 0       سالم و پلمپ          NaN         NaN  سالم و بی‌خط و خش    ۱۲ ماه
# 1               NaN          NaN         NaN  سالم و بی‌خط و خش       NaN
# 2       سالم و پلمپ          NaN         NaN  سالم و بی‌خط و خش       NaN
# 3               NaN          NaN         NaN  سالم و بی‌خط و خش       NaN
# 4       سالم و پلمپ          NaN         NaN  سالم و بی‌خط و خش    ۱۲ ماه
# ...             ...          ...         ...                ...       ...
# 316012  سالم و پلمپ          NaN         NaN           رنگ‌شدگی       NaN
# 316013  سالم و پلمپ          NaN         NaN           رنگ‌شدگی     ۶ ماه
# 316014  سالم و پلمپ          NaN         NaN  سالم و بی‌خط و خش    ۱۲ ماه
# 316015  سالم و پلمپ          NaN         NaN  سالم و بی‌خط و خش    ۱۲ ماه
# 316016  سالم و پلمپ          NaN         NaN  سالم و بی‌خط و خش     ۶ ماه
#
#          Gearbox       Price  Usage  Year      Color  Age
# 0       اتوماتیک  ۱۰۰۰۰۰۰۰۰۰      0  1401       سفید    0
# 1       اتوماتیک  ۱۲۳۰۰۰۰۰۰۰      ۰  1401  سفید صدفی    0
# 2            NaN  ۱۲۴۰۰۰۰۰۰۰      ۰  1401       سفید    0
# 3       اتوماتیک  ۱۲۷۰۰۰۰۰۰۰      ۰  1401     سفید‌‌    0
# 4       اتوماتیک  ۱۲۸۰۰۰۰۰۰۰      0  1401    خاکستری    0
# ...          ...         ...    ...   ...        ...  ...
# 316012   دنده‌ای   ۹۳۰۰۰۰۰۰۰  ۳۰۰۰۰  1400  قهوه‌ای‌‌    1
# 316013   دنده‌ای   ۹۳۰۰۰۰۰۰۰  ۳۰۰۰۰  1400    قهوه‌ای    1
# 316014   دنده‌ای   ۹۸۰۰۰۰۰۰۰   ۸۵۰۰  1400     مشکی‌‌    1
# 316015   دنده‌ای   ۹۹۰۰۰۰۰۰۰  ۱۴۰۰۰  1400       مشکی    1
# 316016  اتوماتیک  ۱۱۰۰۰۰۰۰۰۰  ۱۲۰۰۰  1400       مشکی    1
#
# [316017 rows x 15 columns]

# %%
# df["Price"] = df["Price"].astype(int)

def deleteMOZ():    
    for i in df["Price"]:
        if len(i) >= 12:
            i = "saeed"
df.apply(deleteMOZ)
for i in df["Price"]:
    if len(i) >= 12:
        print(i)

# %% [markdown]
# #### Define dictionary

# %%
x = 0
age = []
for i in df["Year"]:
    # print(i)
    if (i) > 1600:
        age.append(2022-i)
        x += 1
    elif (i) < 1600:
        age.append(1401-i)
        x += 1
df["Age"] = age

# %%
gf = df[["Infos" , "Usage", "Price", "Age"]]

# %%
gf.to_csv("finaldata.csv", encoding="utf-8-sig")

# %% [markdown]
# #### Brand and type dictionary

# %%
# brandDic = {}
# brandDic ['آئودی'] = []
# brandDic ['آریا'] = []
# brandDic ['آریسان'] = []
# brandDic ['آلفارومئو'] = []
# brandDic ['آمیکو'] = []
# brandDic ['اپل'] = []
# brandDic ['اس دبلیو ام'] = []
# brandDic ['اسمارت'] = []
# brandDic ['الدزمبیل'] = []
# brandDic ['ام جی'] = []
# brandDic ['ام وی ام'] = []
# brandDic ['ایسوزو'] = []
# brandDic ['اینرودز'] = []
# brandDic ['اینفینیتی'] = []
# brandDic ['ب ام و'] = []
# brandDic ['بایک'] = []
# brandDic ['برلیانس'] = []
# brandDic ['بسترن'] = []
# brandDic ['بنز'] = []
# brandDic ['بورگوارد'] = []
# brandDic ['بی وای دی'] = []
# brandDic ['بیسو'] = []
# brandDic ['بیوک'] = []
# brandDic ['پاژن'] = []
# brandDic ['پراید'] = []
# brandDic ['پروتون'] = []
# brandDic ['پژو'] = []
# brandDic ['پورشه'] = []
# brandDic ['پونتیاک'] = []
# brandDic ['پیکان'] = []
# brandDic ['تارا'] = []
# brandDic ['تویوتا'] = []
# brandDic ['تیبا'] = []
# brandDic ['جک'] = []
# brandDic ['جی ام سی GMC'] = []
# brandDic ['جِی ام سی JMC'] = []
# brandDic ['جیپ'] = []
# brandDic ['جیلی'] = []
# brandDic ['چانگان'] = []
# brandDic ['چری'] = []
# brandDic ['داتسون'] = []
# brandDic ['دامای'] = []
# brandDic ['دانگ فنگ'] = []
# brandDic ['دایون'] = []
# brandDic ['دنا'] = []
# brandDic ['دوج'] = []
# brandDic ['دوو'] = []
# brandDic ['دی اس'] = []
# brandDic ['دیگنیتی'] = []
# brandDic ['رانا'] = []
# brandDic ['راین'] = []
# brandDic ['رنو'] = []
# brandDic ['ریگان'] = []
# brandDic ['زامیاد'] = []
# brandDic ['زوتی'] = []
# brandDic ['سانگ یانگ'] = []
# brandDic ['ساینا'] = []
# brandDic ['سئات'] = []
# brandDic ['سمند'] = []
# brandDic ['سوئیست'] = []
# brandDic ['سوبارو'] = []
# brandDic ['سوزوکی'] = []
# brandDic ['سیتروئن'] = []
# brandDic ['سیناد'] = []
# brandDic ['شاهین'] = []
# brandDic ['شورولت'] = []
# brandDic ['فردا'] = []
# brandDic ['فوتون'] = []
# brandDic ['فورد'] = []
# brandDic ['فولکس'] = []
# brandDic ['فونیکس'] = []
# brandDic ['فیات'] = []
# brandDic ['فیدلیتی'] = []
# brandDic ['کاپرا'] = []
# brandDic ['کادیلاک'] = []
# brandDic ['کارا'] = []
# brandDic ['کوییک'] = []
# brandDic ['کی ام سی'] = []
# brandDic ['کیا'] = []
# brandDic ['گریت وال'] = []
# brandDic ['گک'] = []
# brandDic ['لاماری'] = []
# brandDic ['لکسوس'] = []
# brandDic ['لندرور'] = []
# brandDic ['لندمارک'] = []
# brandDic ['لوتوس'] = []
# brandDic ['لیفان'] = []
# brandDic ['لینکلن'] = []
# brandDic ['مازراتی'] = []
# brandDic ['مزدا'] = []
# brandDic ['مکث موتور'] = []
# brandDic ['میتسوبیشی'] = []
# brandDic ['مینی'] = []
# brandDic ['نیسان'] = []
# brandDic ['ولوو'] = []
# brandDic ['ون'] = []
# brandDic ['هامر'] = []
# brandDic ['هاوال'] = []
# brandDic ['هایما'] = []
# brandDic ['هن تنگ'] = []
# brandDic ['هوندا'] = []
# brandDic ['هیلمن'] = []
# brandDic ['هیوسو'] = []
# brandDic ['هیوندای'] = []
# brandDic ['یوآز'] = []

# %% [markdown]
# #### Locate

# %%
# def locate(i):
#     return df[i:(i+1)]
# # df[2:3]
# locate(0)

# %%
# for i in range(len(df.index)):
#     # print(type(df['Price'][i]))
#         # print(df.loc[[79]])
#         # df.drop(index=[i], axis=0, inplace=True)
#         # print("diiiiiiiiiiiizzzzzzz")
        
#         # df.drop([i])
#         # df[i]
#         # df.loc[:,i]
    
#     # # print(type(i))
#     if type(df['Usage'][i]) ==  str:
#         df['Usage'][i] = int((df['Usage'][i]).replace('٬', '').replace('\u200c', ''))
        
#     if type(df['Price'][i]) ==  str:
#         df['Price'][i] = float((df['Price'][i]).replace('٬', '').replace('\u200c', ''))
    
#     if type(df['Year'][i]) ==  str:
#         df['Year'][i] = int((df['Year'][i]).replace('٬', '').replace('\u200c', ''))
#         # (df['Price'][i]).replace(",","")
#         # print(df['Price'][i])
#         # print(i)

# %%
df

# %%
# # for (k, v) in map:
# #     for c in v:
# #         text = text.replace(c, k)

# # def processString3(txt):
# #   txt = txt.replace('\u200c', '')

# # for i in df["Infos"]:
# #   processString3(i)
# # processString3(mimi)
# # processString3(txt)
# print(df.Infos.nunique())
# print(df.Infos.unique())

# %% [markdown]
# #### Renaming the column names

# %%
# df = df.rename({'Year': 'Age'}, axis=1)  # new method

# %% [markdown]
# #### a code for normalizing the strings

# %%
map = dict()
map[' '] = ['‌']
map['آ'] = []
map['ب'] = []
map['پ'] = []
map['ت'] = ['ٿ', 'ټ', 'ٺ', 'ت', 'ٹ']
map['ث'] = ['ٽ', 'ث']
map['ج'] = []
map['چ'] = ['ڇ', 'چ', 'ڄ', 'ڃ']
map['ح'] = ['ځ', 'ح']
map['خ'] = ['ڿ', 'خ', 'څ', 'ڂ', 'خ']
map['د'] = ['ډ', 'ڈ', 'ۮ', 'د']
map['ذ'] = ['ڐ', 'ڏ', 'ڎ', 'ڍ', 'ڌ', 'ڊ', 'ڋ', 'ذ']
map['ر'] = ['ږ', 'ڕ', 'ڔ', 'ړ', 'ڒ', 'ر']
map['ز'] = []
map['ژ'] = ['ۯ', 'ڙ', 'ژ', 'ڗ']
map['س'] = ['ښ', 'س']
map['ش'] = ['ۺ', 'ڜ', 'ڛ', 'ش']
map['ص'] = ['ص', 'ڝ']
map['ض'] = ['ۻ', 'ض', 'ڞ']
map['ط'] = []
map['ظ'] = ['ڟ', 'ظ']
map['ع'] = []
map['غ'] = ['ۼ', 'غ', 'ڠ']
map['ف'] = ['ڦ', 'ڥ', 'ڤ', 'ڣ', 'ڢ', 'ڡ', 'ف']
map['ق'] = ['ڨ', 'ڧ', 'ٯ', 'ق']
map['ک'] = ['ؼ', 'ػ', 'ڪ', 'ک', 'ګ', 'ڬ', 'ڭ', 'ك', 'ڮ']
map['گ'] = ['گ', 'ڰ', 'ڱ', 'ڲ', 'ڳ', 'ڴ']
map['ل'] = ['ڵ', 'ڶ', 'ڷ', 'ڸ', 'ل']
map['م'] = ['۾', 'م']
map['ن'] = ['ن', 'ڽ', 'ڼ', 'ڻ', 'ں', 'ڹ']
map['و'] = ['ؤ', 'و', 'ٷ', 'ٶ', 'ۏ', 'ۋ', 'ۊ', 'ۉ', 'ۈ', 'ۇ', 'ۆ', 'ۅ', 'ۄ']
map['ھ'] = ['ۿ', 'ھ']
map['ه'] = ['ە', 'ۂ', 'ہ', 'ۀ', 'ه']
map['ة'] = ['ة', 'ۃ']
map['ی'] = ['ئ', 'ؠ', 'ؿ', 'ؾ', 'ؽ', 'ي', 'ى', 'ٸ', 'ی', 'ۍ', 'ێ', 'ۑ', 'ې', 'ۓ', 'ے']

text = "unnormal tex"
for (k, v) in map:
    for c in v:
        text = text.replace(c, k)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\saeed\Desktop\Mozayedegar\Divar-Scraping\PriceEstimatorCleaner.ipynb Cell 21 in <cell line: 39>()
#      <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/PriceEstimatorCleaner.ipynb#X25sZmlsZQ%3D%3D?line=35'>36</a> map['ی'] = ['ئ', 'ؠ', 'ؿ', 'ؾ', 'ؽ', 'ي', 'ى', 'ٸ', 'ی', 'ۍ', 'ێ', 'ۑ', 'ې', 'ۓ', 'ے']
#      <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/PriceEstimatorCleaner.ipynb#X25sZmlsZQ%3D%3D?line=37'>38</a> text = "unnormal tex"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/PriceEstimatorCleaner.ipynb#X25sZmlsZQ%3D%3D?line=38'>39</a> for (k, v) in map:
#      <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/PriceEstimatorCleaner.ipynb#X25sZmlsZQ%3D%3D?line=39'>40</a>     for c in v:
#      <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/PriceEstimatorCleaner.ipynb#X25sZmlsZQ%3D%3D?line=40'>41</a>         text = text.replace(c, k)
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # Estimation

# %%
# The x axis represents the age and the Usage
x = df[['Age', 'Usage']]

# The y axis represents the price
y= df['Price']          

regression = linear_model.LinearRegression()
regression.fit(x,y)

# %%
plt.scatter(df['Age'], y, color='red')
plt.scatter(df['Usage'], y, color='green')
plt.title('Pricetable')
plt.xlabel('Independents')
plt.ylabel('Dependents')
plt.show

# %%
print("INTERCEPT:\n", regression.intercept_)
print("Coefficient:\n" , regression.coef_)

# %%
print(df.Infos.nunique())
print(df.Infos.unique())

# %% [markdown]
# # Get output

# %%
pd.read_json(r"C:\Users\saeed\Downloads\car.json", encoding = "utf8")
