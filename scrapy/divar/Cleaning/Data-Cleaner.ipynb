# %%
import pandas as pd
import re

# %%
filename = "10oct"
read_file = pd.read_csv('19sep.csv')
read_file.to_csv("%s.csv"%filename, encoding='utf-8-sig', index=None,
                 header=True)

# %%
df = pd.read_csv(r'./%s.csv'%filename, encoding='utf8')
df = pd.DataFrame(df)
df
# Out:
#                            Page link  \
# 0      https://divar.ir/v/-/wYCV3y7b
# 1      https://divar.ir/v/-/wYCVXauG
# 2      https://divar.ir/v/-/wYugdmbx
# 3      https://divar.ir/v/-/wYCRH66f
# 4      https://divar.ir/v/-/wY1sTtU_
# ...                              ...
# 24619  https://divar.ir/v/-/wYnYUoNY
# 24620  https://divar.ir/v/-/wYnYUn6Y
# 24621  https://divar.ir/v/-/wYfImP_q
# 24622  https://divar.ir/v/-/wYnYkmJY
# 24623  https://divar.ir/v/-/wYnYE1Xq
#
#                                                    Infos  \
# 0      برند و تیپ, وضعیت موتور, سالم, وضعیت شاسی\u200...
# 1      برند و تیپ, وضعیت موتور, سالم, شاسی جلو, ضربه\...
# 2      برند و تیپ, وضعیت موتور, سالم, وضعیت شاسی\u200...
# 3      برند و تیپ, وضعیت موتور, سالم, شاسی جلو, رنگ\u...
# 4      برند و تیپ, وضعیت شاسی\u200cها, سالم و پلمپ, و...
# ...                                                  ...
# 24619                                  پیکان وانت بنزینی
# 24620                                       پراید 131 SE
# 24621                                کیا اسپورتیج 2400cc
# 24622                        پراید صندوق\u200cدار بنزینی
# 24623                                       پراید 131 SE
#
#                                                    test2  \
# 0                                     پژو 405 GLX بنزینی
# 1                                    پژو پارس دوگانه سوز
# 2                                  ام‌وی‌ام 110 ۳ سیلندر
# 3                                      تیبا صندوق‌دار SX
# 4                             کیا سورنتو GT Line نسل سوم
# ...                                                  ...
# 24619  برند و تیپ,وضعیت موتور,سالم,شاسی جلو,ضربه‌خورد...
# 24620  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...
# 24621  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...
# 24622  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...
# 24623  برند و تیپ,وضعیت موتور,سالم,شاسی عقب,سالم و پل...
#
#                Distance Year Color
# 0            ۹۲٬۰۰۰, 1398, خاکستری
# 1              ۱۹۰٬۰۰۰, 1395, سفید
# 2             ۱۵۰٬۰۰۰, 1388, عنابی
# 3               ۳۲٬۰۰۰, 1398, سفید
# 4               ۸۶٬۰۰۰, 2017, مشکی
# ...                            ...
# 24619          ۱۲۰٬۰۰۰, 1390, سفید
# 24620           ۶۲٬۰۰۰, 1396, سفید
# 24621  ۱۱۰٬۰۰۰, 2012, قهوه\u200cای
# 24622          ۲۸۰٬۰۰۰, 1382, سفید
# 24623           ۵۷٬۰۰۰, 1395, سفید
#
# [24624 rows x 4 columns]

# %%
motor = []
chassis = []
fchassis = []
bchassis = []
bodys = []
insurance = []
gearbox = []
price = []
distance = []
year = []
color = []

for i in range(len(df.index)):
    dyc = re.findall(r"(.*), (.*), (.*)", df['Distance Year Color'][i])
    # print(dyc)
    distance.append(dyc[0][0])
    year.append(dyc[0][1])
    color.append(dyc[0][2])
    

    motor.append(re.findall(r", وضعیت موتور,(.*?),", df['Infos'][i]))
    chassis.append(re.findall(r", وضعیت شاسی‌ها,(.*?),", df['Infos'][i]))
    insurance.append(re.findall(
        r", مهلت بیمهٔ شخص ثالث,(.*?),", df['Infos'][i]))
    fchassis.append(re.findall(r", شاسی جلو,(.*?),", df['Infos'][i]))
    bchassis.append(re.findall(r", شاسی عقب,(.*?),", df['Infos'][i]))
    bodys.append(re.findall(r", وضعیت بدنه,(.*?),", df['Infos'][i]))
    gearbox.append(re.findall(r", گیربکس,(.*?),", df['Infos'][i]))
    price.append(re.findall(r", قیمت فروش نقدی,(.*) تومان", df['Infos'][i]))

    # print(df['test2'][i])
    # i +=1

df['MotorState'] = motor 
df['ChassisState'] = chassis 
df['FrontChassis'] = fchassis 
df['BackChassis'] = bchassis 
df['BodyState'] = bodys 
df['Insurance'] = insurance 
df['Gearbox'] = gearbox 
df['Price'] = price 
df['Usage'] = distance
df['Year'] = year
df['Color'] = color

print(df)
# type(df)
# Out:
#                            Page link  \
# 0      https://divar.ir/v/-/wYCV3y7b
# 1      https://divar.ir/v/-/wYCVXauG
# 2      https://divar.ir/v/-/wYugdmbx
# 3      https://divar.ir/v/-/wYCRH66f
# 4      https://divar.ir/v/-/wY1sTtU_
# ...                              ...
# 24619  https://divar.ir/v/-/wYnYUoNY
# 24620  https://divar.ir/v/-/wYnYUn6Y
# 24621  https://divar.ir/v/-/wYfImP_q
# 24622  https://divar.ir/v/-/wYnYkmJY
# 24623  https://divar.ir/v/-/wYnYE1Xq
#
#                                                    Infos  \
# 0      برند و تیپ, وضعیت موتور, سالم, وضعیت شاسی\u200...
# 1      برند و تیپ, وضعیت موتور, سالم, شاسی جلو, ضربه\...
# 2      برند و تیپ, وضعیت موتور, سالم, وضعیت شاسی\u200...
# 3      برند و تیپ, وضعیت موتور, سالم, شاسی جلو, رنگ\u...
# 4      برند و تیپ, وضعیت شاسی\u200cها, سالم و پلمپ, و...
# ...                                                  ...
# 24619                                  پیکان وانت بنزینی
# 24620                                       پراید 131 SE
# 24621                                کیا اسپورتیج 2400cc
# 24622                        پراید صندوق\u200cدار بنزینی
# 24623                                       پراید 131 SE
#
#                                                    test2  \
# 0                                     پژو 405 GLX بنزینی
# 1                                    پژو پارس دوگانه سوز
# 2                                  ام‌وی‌ام 110 ۳ سیلندر
# 3                                      تیبا صندوق‌دار SX
# 4                             کیا سورنتو GT Line نسل سوم
# ...                                                  ...
# 24619  برند و تیپ,وضعیت موتور,سالم,شاسی جلو,ضربه‌خورد...
# 24620  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...
# 24621  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...
# 24622  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...
# 24623  برند و تیپ,وضعیت موتور,سالم,شاسی عقب,سالم و پل...
#
#                Distance Year Color MotorState ChassisState  \
# 0            ۹۲٬۰۰۰, 1398, خاکستری    [ سالم]           []
# 1              ۱۹۰٬۰۰۰, 1395, سفید    [ سالم]           []
# 2             ۱۵۰٬۰۰۰, 1388, عنابی    [ سالم]           []
# 3               ۳۲٬۰۰۰, 1398, سفید    [ سالم]           []
# 4               ۸۶٬۰۰۰, 2017, مشکی         []           []
# ...                            ...        ...          ...
# 24619          ۱۲۰٬۰۰۰, 1390, سفید         []           []
# 24620           ۶۲٬۰۰۰, 1396, سفید         []           []
# 24621  ۱۱۰٬۰۰۰, 2012, قهوه\u200cای         []           []
# 24622          ۲۸۰٬۰۰۰, 1382, سفید         []           []
# 24623           ۵۷٬۰۰۰, 1395, سفید         []           []
#
#              FrontChassis     BackChassis                  BodyState  \
# 0                      []              []  [ سالم و بی\u200cخط و خش]
# 1      [ ضربه\u200cخورده]  [ سالم و پلمپ]            [ خط و خش جزیی]
# 2                      []              []           [ تمام\u200cرنگ]
# 3         [ رنگ\u200cشده]  [ سالم و پلمپ]           [ رنگ\u200cشدگی]
# 4                      []              []  [ سالم و بی\u200cخط و خش]
# ...                   ...             ...                        ...
# 24619                  []              []                         []
# 24620                  []              []                         []
# 24621                  []              []                         []
# 24622                  []              []                         []
# 24623                  []              []                         []
#
#       Insurance          Gearbox             Price    Usage  Year  \
# 0      [ ۲ ماه]  [ دنده\u200cای]    [ ۲۲۷٬۰۰۰٬۰۰۰]   ۹۲٬۰۰۰  1398
# 1      [ ۵ ماه]  [ دنده\u200cای]    [ ۲۴۵٬۰۰۰٬۰۰۰]  ۱۹۰٬۰۰۰  1395
# 2      [ ۶ ماه]  [ دنده\u200cای]     [ ۷۲٬۰۰۰٬۰۰۰]  ۱۵۰٬۰۰۰  1388
# 3      [ ۷ ماه]  [ دنده\u200cای]    [ ۱۵۸٬۰۰۰٬۰۰۰]   ۳۲٬۰۰۰  1398
# 4            []               []  [ ۲٬۹۰۰٬۰۰۰٬۰۰۰]   ۸۶٬۰۰۰  2017
# ...         ...              ...               ...      ...   ...
# 24619        []               []                []  ۱۲۰٬۰۰۰  1390
# 24620        []               []                []   ۶۲٬۰۰۰  1396
# 24621        []               []                []  ۱۱۰٬۰۰۰  2012
# 24622        []               []                []  ۲۸۰٬۰۰۰  1382
# 24623        []               []                []   ۵۷٬۰۰۰  1395
#
#               Color
# 0           خاکستری
# 1              سفید
# 2             عنابی
# 3              سفید
# 4              مشکی
# ...             ...
# 24619          سفید
# 24620          سفید
# 24621  قهوه\u200cای
# 24622          سفید
# 24623          سفید
#
# [24624 rows x 15 columns]

# %%
df
# Out:
#                            Page link  \
# 0      https://divar.ir/v/-/wYCV3y7b
# 1      https://divar.ir/v/-/wYCVXauG
# 2      https://divar.ir/v/-/wYugdmbx
# 3      https://divar.ir/v/-/wYCRH66f
# 4      https://divar.ir/v/-/wY1sTtU_
# ...                              ...
# 24619  https://divar.ir/v/-/wYnYUoNY
# 24620  https://divar.ir/v/-/wYnYUn6Y
# 24621  https://divar.ir/v/-/wYfImP_q
# 24622  https://divar.ir/v/-/wYnYkmJY
# 24623  https://divar.ir/v/-/wYnYE1Xq
#
#                                                    Infos MotorState  \
# 0                                     پژو 405 GLX بنزینی    [ سالم]
# 1                                    پژو پارس دوگانه سوز    [ سالم]
# 2                                  ام‌وی‌ام 110 ۳ سیلندر    [ سالم]
# 3                                      تیبا صندوق‌دار SX    [ سالم]
# 4                             کیا سورنتو GT Line نسل سوم         []
# ...                                                  ...        ...
# 24619  برند و تیپ,وضعیت موتور,سالم,شاسی جلو,ضربه‌خورد...         []
# 24620  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...         []
# 24621  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...         []
# 24622  برند و تیپ,وضعیت موتور,سالم,وضعیت شاسی‌ها,سالم...         []
# 24623  برند و تیپ,وضعیت موتور,سالم,شاسی عقب,سالم و پل...         []
#
#       ChassisState        FrontChassis     BackChassis  \
# 0               []                  []              []
# 1               []  [ ضربه\u200cخورده]  [ سالم و پلمپ]
# 2               []                  []              []
# 3               []     [ رنگ\u200cشده]  [ سالم و پلمپ]
# 4               []                  []              []
# ...            ...                 ...             ...
# 24619           []                  []              []
# 24620           []                  []              []
# 24621           []                  []              []
# 24622           []                  []              []
# 24623           []                  []              []
#
#                        BodyState Insurance          Gearbox             Price  \
# 0      [ سالم و بی\u200cخط و خش]  [ ۲ ماه]  [ دنده\u200cای]    [ ۲۲۷٬۰۰۰٬۰۰۰]
# 1                [ خط و خش جزیی]  [ ۵ ماه]  [ دنده\u200cای]    [ ۲۴۵٬۰۰۰٬۰۰۰]
# 2               [ تمام\u200cرنگ]  [ ۶ ماه]  [ دنده\u200cای]     [ ۷۲٬۰۰۰٬۰۰۰]
# 3               [ رنگ\u200cشدگی]  [ ۷ ماه]  [ دنده\u200cای]    [ ۱۵۸٬۰۰۰٬۰۰۰]
# 4      [ سالم و بی\u200cخط و خش]        []               []  [ ۲٬۹۰۰٬۰۰۰٬۰۰۰]
# ...                          ...       ...              ...               ...
# 24619                         []        []               []                []
# 24620                         []        []               []                []
# 24621                         []        []               []                []
# 24622                         []        []               []                []
# 24623                         []        []               []                []
#
#          Usage  Year         Color
# 0       ۹۲٬۰۰۰  1398       خاکستری
# 1      ۱۹۰٬۰۰۰  1395          سفید
# 2      ۱۵۰٬۰۰۰  1388         عنابی
# 3       ۳۲٬۰۰۰  1398          سفید
# 4       ۸۶٬۰۰۰  2017          مشکی
# ...        ...   ...           ...
# 24619  ۱۲۰٬۰۰۰  1390          سفید
# 24620   ۶۲٬۰۰۰  1396          سفید
# 24621  ۱۱۰٬۰۰۰  2012  قهوه\u200cای
# 24622  ۲۸۰٬۰۰۰  1382          سفید
# 24623   ۵۷٬۰۰۰  1395          سفید
#
# [24624 rows x 13 columns]

# %%
df = df.drop('Distance Year Color', axis=1)
df = df.drop('Infos', axis=1)
df = df.rename({'test2 ': 'Infos'}, axis=1)  # new method
df = df.drop('test2', axis=1)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\saeed\Desktop\Mozayedegar\Divar-Scraping\scrapy\divar\Cleaning\Data-Cleaner.ipynb Cell 5 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/scrapy/divar/Cleaning/Data-Cleaner.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> df = df.drop('Infos', axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/scrapy/divar/Cleaning/Data-Cleaner.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> df = df.rename({'test2': 'Infos'}, axis=1)  # new method
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/scrapy/divar/Cleaning/Data-Cleaner.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> df = df.drop('test2', axis=1)
#       <a href='vscode-notebook-cell:/c%3A/Users/saeed/Desktop/Mozayedegar/Divar-Scraping/scrapy/divar/Cleaning/Data-Cleaner.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> print(df)
#
# File c:\Users\saeed\anaconda3\envs\tf\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\saeed\anaconda3\envs\tf\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File c:\Users\saeed\anaconda3\envs\tf\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File c:\Users\saeed\anaconda3\envs\tf\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File c:\Users\saeed\anaconda3\envs\tf\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['test2'] not found in axis"

# %%
# df = df.rename({'test2': 'Brand'}, axis=1)  # new method
# df = df.rename({'قیمت فروش نقدی': 'Price'}, axis=1)  # new method
# df = df.rename({'قیمت فروش نقدی': 'Price'}, axis=1)  # new method

# %%
df.to_csv("./%s.csv"%filename, encoding="UTF-8-sig")
